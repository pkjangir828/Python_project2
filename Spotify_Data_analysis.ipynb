# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_tracks=pd.read_csv(r'C:\Users\PAWAN\Downloads\archive\tracks.csv',encoding='unicode_escape')
# Out:
#   Cell In[181], line 1
#     df_tracks=pd.read_csv('C:\Users\PAWAN\Downloads\archive\tracks.csv',encoding='unicode_escape')
#                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df_tracks.head()
# Out:
#                        id                                  name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                 Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  CapÃ­tulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc    Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45         El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                   Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
pd.isnull(df_tracks).sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
sorted_df=df_tracks.sort_values('popularity',ascending = True,axis=0).head(10)

# %%
sorted_df
# Out:
#                          id                                              name  \
# 21   0wA4YFw7ZNnpasfjVgJxpv              CapÃ­tulo 1.22 - Banquero Anarquista
# 22   0xJCJ9XSNcdTIz0QKmhtEn                         La Maleva - Remasterizado
# 23   0zyKYuXwmo8eR3BBxoxVEO               CapÃ­tulo 2.3 - Banquero Anarquista
# 24   10XXG7gG75jIREUaModzOY               CapÃ­tulo 1.2 - Banquero Anarquista
# 25   10u9ZWsOnhEyqFJCC2rQVy                               J'ai Vendu Mon Ãme
# 27   15BEv0mKGqHHxyDAcLJ7ei           En la Huella del Querer - Remasterizado
# 28   1CZkVPFUK7wO1sMOlBHxJr                       C'est La Mode Et Voila Tout
# 29   1EFtYew3kxq3gP55juunCR  Chapter 1.6 - Szkolne przygody Pimpusia SadeÅko
# 133  6eew1OP57TeUDUMcjYE6A0                       La Muchacha - Remasterizado
# 134  6hH0kKnTWoGq5wppHKj5ie                                          Stardust
#
#      popularity  duration_ms  explicit               artists  \
# ...

# %%
df_tracks.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        586672.0      27.570053      18.370642     0.0      13.0000
# duration_ms       586672.0  230051.167286  126526.087418  3344.0  175093.0000
# explicit          586672.0       0.044086       0.205286     0.0       0.0000
# danceability      586672.0       0.563594       0.166103     0.0       0.4530
# energy            586672.0       0.542036       0.251923     0.0       0.3430
# key               586672.0       5.221603       3.519423     0.0       2.0000
# loudness          586672.0     -10.206067       5.089328   -60.0     -12.8910
# mode              586672.0       0.658797       0.474114     0.0       0.0000
# speechiness       586672.0       0.104864       0.179893     0.0       0.0340
# acousticness      586672.0       0.449863       0.348837     0.0       0.0969
# instrumentalness  586672.0       0.113451       0.266868     0.0       0.0000
# ...

# %%
df_top=df_tracks.loc[df_tracks['popularity']>90].sort_values('popularity',ascending=False)

# %%
df_top.head(10)
# Out:
#                                   id                                    name  \
# release_date
# 2021-03-19    4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 2021-01-08    7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 2021-01-06    3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 2020-12-04    6tDDoYIxWvMLTdKpjFkc1B                              telepatÃ­a
# 2020-03-20    5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 2020-03-20    0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 2021-03-05    7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 2020-09-16    6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 2019-11-07    60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 2021-02-04    7Bk0uXKk1uPT0XuQbpFzvs                                    Fiel
#
#               popularity  duration_ms  explicit  \
# release_date
# ...

# %%
most_popular=df_tracks.query('popularity>90',inplace=False).sort_values('popularity',ascending=False).head(10)

# %%
most_popular
# Out:
#                                   id                                    name  \
# release_date
# 2021-03-19    4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 2021-01-08    7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 2021-01-06    3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 2020-12-04    6tDDoYIxWvMLTdKpjFkc1B                              telepatÃ­a
# 2020-03-20    5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 2020-03-20    0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 2021-03-05    7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 2020-09-16    6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 2019-11-07    60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 2021-02-04    7Bk0uXKk1uPT0XuQbpFzvs                                    Fiel
#
#               popularity  duration_ms  explicit  \
# release_date
# ...

# %%
df_tracks.set_index("release_date")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23424\969209935.py in ?()
# ----> 1 df_tracks.set_index("release_date")
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['release_date'] are in the columns"

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 2019-11-07 to 2021-02-11
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                37 non-null     object
#  1   name              37 non-null     object
#  2   popularity        37 non-null     int64
#  3   duration_ms       37 non-null     int64
#  4   explicit          37 non-null     int64
#  5   artists           37 non-null     object
#  6   id_artists        37 non-null     object
#  7   danceability      37 non-null     float64
#  8   energy            37 non-null     float64
#  9   key               37 non-null     int64
#  10  loudness          37 non-null     float64
#  11  mode              37 non-null     int64
#  12  speechiness       37 non-null     float64
#  13  acousticness      37 non-null     float64
#  14  instrumentalness  37 non-null     float64
#  15  liveness          37 non-null     float64
# ...

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 2019-11-07 to 2021-02-11
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                37 non-null     object
#  1   name              37 non-null     object
#  2   popularity        37 non-null     int64
#  3   duration_ms       37 non-null     int64
#  4   explicit          37 non-null     int64
#  5   artists           37 non-null     object
#  6   id_artists        37 non-null     object
#  7   danceability      37 non-null     float64
#  8   energy            37 non-null     float64
#  9   key               37 non-null     int64
#  10  loudness          37 non-null     float64
#  11  mode              37 non-null     int64
#  12  speechiness       37 non-null     float64
#  13  acousticness      37 non-null     float64
#  14  instrumentalness  37 non-null     float64
#  15  liveness          37 non-null     float64
# ...

# %%
df=pd.read_csv(r'C:\Users\PAWAN\Downloads\archive\tracks.csv',encoding='unicode_escape')

# %%
df
# Out:
#                             id                                  name  \
# 0       35iwgR4jXetI318WEWsa1Q                                 Carve
# 1       021ht4sdgPcrDgSk7JTbKY  CapÃ­tulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc    Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45         El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                   Lady of the Evening
# ...                        ...                                   ...
# 586667  5rgu12WBIHQtvej2MdHSH0                             äºä¸æµ·
# 586668  0NuWgxEp51CutD2pJoF4OM                                 blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2             What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                       A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                      Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
 # df.set_index("release_date",inplace=True)
# df.index=pd.to_datetime(df.index)
df.head()
# Out:
#                                   id                                  name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                 Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  CapÃ­tulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc    Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45         El Prisionero - Remasterizado
# 1922          08y9GfoqCWfOGsKdwojr5e                   Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22             6       126903         0              ['Uli']
# 1922-06-01             0        98200         0  ['Fernando Pessoa']
# 1922-03-21             0       181640         0  ['Ignacio Corsini']
# 1922-03-21             0       176907         0  ['Ignacio Corsini']
# 1922                   0       163080         0      ['Dick Haymes']
#
# ...

# %%
df["artists"].iloc[18]
# Out:
# "['Victor Boucher']"

# %%
df["duration"] =df["duration_ms"].div(1000).round()
# Out:
# release_date
# 1922-02-22    0.0
# 1922-06-01    0.0
# 1922-03-21    0.0
# 1922-03-21    0.0
# 1922          0.0
#              ...
# 2020-09-26    0.0
# 2020-10-21    0.0
# 2020-09-02    0.0
# 2021-03-05    0.0
# 2015-07-01    0.0
# Name: duration, Length: 586672, dtype: float64

# %%
df.drop("duration_ms",inplace=True,axis=1)

# %%
df.head()
# Out:
#                                   id                                  name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                 Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  CapÃ­tulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc    Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45         El Prisionero - Remasterizado
# 1922          08y9GfoqCWfOGsKdwojr5e                   Lady of the Evening
#
#               popularity  explicit              artists  \
# release_date
# 1922-02-22             6         0              ['Uli']
# 1922-06-01             0         0  ['Fernando Pessoa']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922                   0         0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# ...

# %%
df1=pd.read_csv(r'C:\Users\PAWAN\Downloads\archive\tracks.csv',encoding='unicode_escape')

# %%
df1.head()
# Out:
#                        id                                  name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                 Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  CapÃ­tulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc    Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45         El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                   Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
df1["duration"] =df1["duration_ms"].div(1000).round()

# %%
df1["duration"]
# Out:
# 0         127.0
# 1          98.0
# 2         182.0
# 3         177.0
# 4         163.0
#           ...
# 586667    258.0
# 586668    153.0
# 586669    188.0
# 586670    142.0
# 586671    214.0
# Name: duration, Length: 586672, dtype: float64

# %%
df1.head()
# Out:
#                        id                                  name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                 Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  CapÃ­tulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc    Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45         El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                   Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
df1.drop("duration_ms",inplace=True,axis=1)

# %%
df1["duration"].astype('int')
# Out:
# 0         127
# 1          98
# 2         182
# 3         177
# 4         163
#          ...
# 586667    258
# 586668    153
# 586669    188
# 586670    142
# 586671    214
# Name: duration, Length: 586672, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   explicit          586672 non-null  int64
#  4   artists           586672 non-null  object
#  5   id_artists        586672 non-null  object
#  6   release_date      586672 non-null  object
#  7   danceability      586672 non-null  float64
#  8   energy            586672 non-null  float64
#  9   key               586672 non-null  int64
#  10  loudness          586672 non-null  float64
#  11  mode              586672 non-null  int64
#  12  speechiness       586672 non-null  float64
#  13  acousticness      586672 non-null  float64
#  14  instrumentalness  586672 non-null  float64
#  15  liveness          586672 non-null  float64
# ...

# %%
df1_=df1.drop(["key","mode","explicit"],axis=1).corr(method="pearson")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 df1_=df1.drop(["key","mode","explicit"],axis=1).corr(method="pearson")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
df1.head()
# Out:
#                        id                                  name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                 Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  CapÃ­tulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc    Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45         El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                   Lady of the Evening           0
#
#    explicit              artists                  id_artists release_date  \
# 0         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']         1922
#
# ...

# %%
df1.set_index("release_date",inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 586672 entries, 1922-02-22 to 2015-07-01
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   explicit          586672 non-null  int64
#  4   artists           586672 non-null  object
#  5   id_artists        586672 non-null  object
#  6   danceability      586672 non-null  float64
#  7   energy            586672 non-null  float64
#  8   key               586672 non-null  int64
#  9   loudness          586672 non-null  float64
#  10  mode              586672 non-null  int64
#  11  speechiness       586672 non-null  float64
#  12  acousticness      586672 non-null  float64
#  13  instrumentalness  586672 non-null  float64
#  14  liveness          586672 non-null  float64
# ...

# %%
df1_=df1.drop(["key","id","name","artists","id_artists","mode","explicit"],axis=1).corr(method="pearson")

# %%
df1_
# Out:
#                   popularity  danceability    energy  loudness  speechiness  \
# popularity          1.000000      0.187000  0.302315  0.327028    -0.047357
# danceability        0.187000      1.000000  0.241563  0.251436     0.199310
# energy              0.302315      0.241563  1.000000  0.764735    -0.053506
# loudness            0.327028      0.251436  0.764735  1.000000    -0.167112
# speechiness        -0.047357      0.199310 -0.053506 -0.167112     1.000000
# acousticness       -0.370882     -0.242951 -0.715412 -0.519423     0.069060
# instrumentalness   -0.236487     -0.225900 -0.195839 -0.329306    -0.102440
# liveness           -0.048740     -0.106168  0.124632  0.029529     0.207047
# valence             0.004643      0.528150  0.372276  0.275448     0.046501
# tempo               0.071364     -0.040783  0.230099  0.189288    -0.086911
# time_signature      0.086759      0.146196  0.188983  0.164377    -0.114171
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df1_,annot=True,vmin=-1,vmax=1,center=0,linewidth=1)
plt.title("correlation heatmap between variable")
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5]),
#  [Text(0, 0.5, 'popularity'),
#   Text(0, 1.5, 'danceability'),
#   Text(0, 2.5, 'energy'),
#   Text(0, 3.5, 'loudness'),
#   Text(0, 4.5, 'speechiness'),
#   Text(0, 5.5, 'acousticness'),
#   Text(0, 6.5, 'instrumentalness'),
#   Text(0, 7.5, 'liveness'),
#   Text(0, 8.5, 'valence'),
#   Text(0, 9.5, 'tempo'),
#   Text(0, 10.5, 'time_signature'),
#   Text(0, 11.5, 'duration')])

# %%
sample_df1=df1.sample(int(0.004*len(df1)))

# %%
print(len(sample_df1))
# Out:
# 2346

# %%
plt.figure(figsize=(10,6))

# %%
sns.regplot(data=sample_df1,y="loudness",x="energy",color="c").set_title("Loudness vs Energy Correlation")
# Out:
# Text(0.5, 1.0, 'Loudness vs Energy Correlation')

# %%
sns.regplot(data=sample_df1,y="popularity",x="acousticness",color="y").set_title("Energy vspopularity Correlation")
# Out:
# Text(0.5, 1.0, 'Energy vspopularity Correlation')

# %%
df_genre=pd.read_csv(r'C:\Users\PAWAN\Downloads\archive\SpotifyFeatures.csv',encoding='unicode_escape')

# %%
df_genre.head()
# Out:
#   ï»¿genre         artist_name                        track_name  \
# 0    Movie      Henri Salvador       C'est beau de faire un Show
# 1    Movie  Martin & les fÃ©es  Perdu d'avance (par Gad Elmaleh)
# 2    Movie     Joseph Williams    Don't Let Me Be Lonely Tonight
# 3    Movie      Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4    Movie        Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
df_genre.rename(columns = {'ï»¿genre':'type'}, inplace = True)
# df_genre.head()

# %%
plt.figure(figsize=(15,8))
plt.title("Duration of the songs in different genre")
# sns.color_palette("rocket",as_cmap=True)
sns.barplot(data=df_genre,y='gonre',x='duration_ms')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[230], line 4
#       2 plt.title("Duration of the songs in different genre")
#       3 # sns.color_palette("rocket",as_cmap=True)
# ----> 4 sns.barplot(data=df_genre,y='gonre',x='duration_ms')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
# ...

# %%
df_genre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ï»¿genre          232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232724 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
# ...

# %%
df_genr=pd.read_csv(r'C:\Users\PAWAN\Downloads\archive\SpotifyFeatures.csv',encoding='unicode_escape')
df_genr.head()
# Out:
#   ï»¿genre         artist_name                        track_name  \
# 0    Movie      Henri Salvador       C'est beau de faire un Show
# 1    Movie  Martin & les fÃ©es  Perdu d'avance (par Gad Elmaleh)
# 2    Movie     Joseph Williams    Don't Let Me Be Lonely Tonight
# 3    Movie      Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4    Movie        Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
df_genr.rename(columns = {'ï»¿genre':'genre'}, inplace = True)

# %%
df_genr
# Out:
#        ï»¿genre               artist_name                        track_name  \
# 0         Movie            Henri Salvador       C'est beau de faire un Show
# 1         Movie        Martin & les fÃ©es  Perdu d'avance (par Gad Elmaleh)
# 2         Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3         Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4         Movie              Fabien Nataf                         Ouverture
# ...         ...                       ...                               ...
# 232720     Soul                     Slave                      Son Of Slide
# 232721     Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722     Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723     Soul                   R.LUM.R                     With My Words
# 232724     Soul            Mint Condition    You Don't Have To Hurt No More
#
# ...

# %%
sns.barplot(data=df_genr,y='	ï»¿genre',x='duration_ms')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[251], line 1
# ----> 1 sns.barplot(data=df_genr,y='	ï»¿genre',x='duration_ms')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
#    2350 if ax is None:
#    2351     ax = plt.gca()
#
# ...

# %%
df=pd.read_csv(r'C:\Users\PAWAN\Downloads\archive\SpotifyFeatures.csv',encoding='unicode_escape')
df.head()
# Out:
#   ï»¿genre         artist_name                        track_name  \
# 0    Movie      Henri Salvador       C'est beau de faire un Show
# 1    Movie  Martin & les fÃ©es  Perdu d'avance (par Gad Elmaleh)
# 2    Movie     Joseph Williams    Don't Let Me Be Lonely Tonight
# 3    Movie      Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4    Movie        Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
sns.color_palette("rocket", as_cmap=True)
sns.barplot(data=df,x='duration_ms',y='ï»¿genre',color='b')
# Out:
# <Axes: xlabel='duration_ms', ylabel='ï»¿genre'>
# C:\Users\PAWAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128 (\x80) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\PAWAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 153 (\x99) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\PAWAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128 (\x80) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PAWAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 153 (\x99) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.set_style(style='darkgrid')
# sns.color_palette("rocket", as_cmap=True)
plt.figure(figsize=(10,5))
famous=df.sort_values("popularity",ascending=False).head(10)
sns.barplot(y='ï»¿genre',x='popularity',data= famous,hue='ï»¿genre').set(title="Top 5 genre by popularity")
# Out:
# [Text(0.5, 1.0, 'Top 5 genre by popularity')]
